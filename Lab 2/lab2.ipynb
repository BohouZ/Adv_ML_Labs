# %% [markdown]
# # **Lab 2:** Optimization and Normalization

# %% [markdown]
# # Part 0: Enviornment Setup
#
# For this lab and for the final project, you may find it useful to run your code with access to a sufficient GPU, which may allow your code to run faster.

# %%
# This is the path that the dataset for this homework will be downloaded to.
# If you are running on the course server or Colab you can keep this line, if you are
# running on a personal computer, you may want to change this location.
data_path = 'data'

# %%
# Uncomment and run if using Colab!

#import urllib.request
#remote_url = 'https://gist.githubusercontent.com/gabehope/3e574b9d225004ff1a179136c29ef4d5/raw/288949bfc3b768b7603fe4decafbcd589c9a72d5/hw9_support.py'
#with urllib.request.urlopen(remote_url) as remote, open('lab2_support.py', 'w') as local:
#  [local.write(str(line, encoding='utf-8')) for line in remote]

# %%
# This is the path that the dataset for this homework will be downloaded to.
# If you are running on the course server or Colab you can keep this line, if you are
# running on a personal computer, you may want to change this location.
from lab2_support import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Support Code
#
# **There are no problems in this section, but you should read and try to understand the code being shown. Make sure to run all the cells in this section as well.**

# %% [markdown]
# ## Set Hyperparameters

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np

from torchsummary import summary

from torchvision.datasets import FashionMNIST
from torchvision.transforms import Compose, Normalize, ToTensor

from fastprogress.fastprogress import master_bar, progress_bar

import matplotlib.pyplot as plt

# %%
# Use the GPUs if they are available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using '{device}' device.")

# Model hyperparameters
neurons_per_hidden_layer = [20] * 2

# Mini-Batch SGD hyperparameters
batch_size = 256
num_epochs = 10
learning_rate = 0.001

criterion = nn.CrossEntropyLoss()
# Out:
# Using 'cuda' device.

# %% [markdown]
# ## Prepare the Dataset

# %%
def get_fmnist_data_loaders(path, batch_size, valid_batch_size=0):
    # Computing normalization constants for Fashion-MNIST (commented out since we only need to do this once)
    # train_loader, valid_loader = get_fmnist_data_loaders(data_path, 0)
    # X, _ = next(iter(train_loader))
    # s, m = torch.std_mean(X)


    # Data specific transforms
    data_mean = (0.2860,)
    data_std = (0.3530,)
    xforms = Compose([ToTensor(), Normalize(data_mean, data_std)])

    # Training data loader
    train_dataset = FashionMNIST(root=path, train=True, download=True, transform=xforms)

    # Set the batch size to N if batch_size is 0
    tbs = len(train_dataset) if batch_size == 0 else batch_size
    train_loader = DataLoader(train_dataset, batch_size=tbs, shuffle=True)

    # Validation data loader
    valid_dataset = FashionMNIST(root=path, train=False, download=True, transform=xforms)

    # Set the batch size to N if batch_size is 0
    vbs = len(valid_dataset) if valid_batch_size == 0 else valid_batch_size
    valid_loader = DataLoader(valid_dataset, batch_size=vbs, shuffle=True)

    return train_loader, valid_loader

# %%
# Load the example dataset (Fashion MNIST)
train_loader, valid_loader = get_fmnist_data_loaders(data_path, batch_size)

print("Training dataset shape   :", train_loader.dataset.data.shape)
print("Validation dataset shape :", valid_loader.dataset.data.shape)
# Out:
# Training dataset shape   : torch.Size([60000, 28, 28])
# Validation dataset shape : torch.Size([10000, 28, 28])

# %%
# Let's plot a few images as an example
num_to_show = 8
images = train_loader.dataset.data[:num_to_show]
targets = train_loader.dataset.targets[:num_to_show]
labels = [train_loader.dataset.classes[t] for t in targets]

fig, axes = plt.subplots(1, num_to_show)

for axis, image, label in zip(axes, images, labels):
    axis.imshow(image.squeeze(), cmap="Greys")
    axis.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_title(f"{label}")

# %% [markdown]
# ## Create a Neural Network

# %%
class Layer(nn.Module):
    # This class will represent a basic neural network layer with a linear function
    # and an activation (in this case ReLU)
    def __init__(self, in_dimensions, out_dimensions):
        super().__init__()
        self.linear = nn.Linear(in_dimensions, out_dimensions)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.linear(x)
        x = self.activation(x)
        return x

class NeuralNetwork(nn.Module):
    def __init__(self, layer_sizes, layer_class=Layer):
        super(NeuralNetwork, self).__init__()

        # The first "layer" just rearranges the Nx28x28 input into Nx784
        first_layer = nn.Flatten()

        # The hidden layers include:
        # 1. a linear component (computing Z) and
        # 2. a non-linear comonent (computing A)
        hidden_layers = [
            (layer_class(nlminus1, nl) if nlminus1 == nl else Layer(nlminus1, nl))
            for nl, nlminus1 in zip(layer_sizes[1:-1], layer_sizes)
        ]

        # The output layer must be Linear without an activation. See:
        #   https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
        output_layer = nn.Linear(layer_sizes[-2], layer_sizes[-1])

        # Group all layers into the sequential container
        all_layers = [first_layer] + hidden_layers + [output_layer]
        self.layers = nn.Sequential(*all_layers)

    def forward(self, X):
        return self.layers(X)

# %% [markdown]
# ## Implement an Optimizer

# %%
class SGDOptimizer:
    def __init__(self, parameters, lr=0.01):
        # Set the learning rate
        self.lr = lr
        # Store the set of parameters that we'll be optimizing
        self.parameters = list(parameters)

    def step(self):
        # Take a step of gradient descent
        for ind, parameter in enumerate(self.parameters):
            # Compute the update to the parameter
            update = self.lr * parameter.grad

            # Update the parameter: w <- w - lr * grad
            parameter -= update

# %% [markdown]
# ## Train Classifier

# %%
# Here we'll define a function to train and evaluate a neural network with a specified architecture
# using a specified optimizer.
def run_model(optimizer=SGDOptimizer,
              layer_type=Layer,
              number_of_hidden_layers=2,
              neurons_per_hidden_layer=20,
              learning_rate=0.001):

    # Get the dataset
    train_loader, valid_loader = get_fmnist_data_loaders(data_path, batch_size)

    # The input layer size depends on the dataset
    nx = train_loader.dataset.data.shape[1:].numel()

    # The output layer size depends on the dataset
    ny = len(train_loader.dataset.classes)

    # Preprend the input and append the output layer sizes
    layer_sizes = [nx] + [neurons_per_hidden_layer] * number_of_hidden_layers + [ny]

    # Do model creation here so that the model is recreated each time the cell is run
    model = NeuralNetwork(layer_sizes, layer_type).to(device)

    t = 0
    # Create the optimizer, just like we have with the built-in optimizer
    opt = optimizer(model.parameters(), learning_rate)

    # A master bar for fancy output progress
    mb = master_bar(range(num_epochs))

    # Information for plots
    mb.names = ["Train Loss", "Valid Loss"]
    train_losses = []
    valid_losses = []

    for epoch in mb:

        #
        # Training
        #
        model.train()

        train_N = len(train_loader.dataset)
        num_train_batches = len(train_loader)
        train_dataiterator = iter(train_loader)

        train_loss_mean = 0

        for batch in progress_bar(range(num_train_batches), parent=mb):

            # Grab the batch of data and send it to the correct device
            train_X, train_Y = next(train_dataiterator)
            train_X, train_Y = train_X.to(device), train_Y.to(device)

            # Compute the output
            train_output = model(train_X)

            # Compute loss
            train_loss = criterion(train_output, train_Y)

            num_in_batch = len(train_X)
            tloss = train_loss.item() * num_in_batch / train_N
            train_loss_mean += tloss
            train_losses.append(train_loss.item())

            # Compute gradient
            model.zero_grad()
            train_loss.backward()

            # Take a step of gradient descent
            t += 1
            with torch.no_grad():
                opt.step()

        #
        # Validation
        #
        model.eval()

        valid_N = len(valid_loader.dataset)
        num_valid_batches = len(valid_loader)

        valid_loss_mean = 0
        valid_correct = 0

        with torch.no_grad():

            # valid_loader is probably just one large batch, so not using progress bar
            for valid_X, valid_Y in valid_loader:

                valid_X, valid_Y = valid_X.to(device), valid_Y.to(device)

                valid_output = model(valid_X)

                valid_loss = criterion(valid_output, valid_Y)

                num_in_batch = len(valid_X)
                vloss = valid_loss.item() * num_in_batch / valid_N
                valid_loss_mean += vloss
                valid_losses.append(valid_loss.item())

                # Convert network output into predictions (one-hot -> number)
                predictions = valid_output.argmax(1)

                # Sum up total number that were correct
                valid_correct += (predictions == valid_Y).type(torch.float).sum().item()

        valid_accuracy = 100 * (valid_correct / valid_N)

        # Report information
        tloss = f"Train Loss = {train_loss_mean:.4f}"
        vloss = f"Valid Loss = {valid_loss_mean:.4f}"
        vaccu = f"Valid Accuracy = {(valid_accuracy):>0.1f}%"
        mb.write(f"[{epoch+1:>2}/{num_epochs}] {tloss}; {vloss}; {vaccu}")

        # Update plot data
        max_loss = max(max(train_losses), max(valid_losses))
        min_loss = min(min(train_losses), min(valid_losses))

        x_margin = 0.2
        x_bounds = [0 - x_margin, num_epochs + x_margin]

        y_margin = 0.1
        y_bounds = [min_loss - y_margin, max_loss + y_margin]

        valid_Xaxis = torch.linspace(0, epoch + 1, len(train_losses))
        valid_xaxis = torch.linspace(1, epoch + 1, len(valid_losses))
        graph_data = [[valid_Xaxis, train_losses], [valid_xaxis, valid_losses]]

        mb.update_graph(graph_data, x_bounds, y_bounds)

    print(f"[{epoch+1:>2}/{num_epochs}] {tloss}; {vloss}; {vaccu}")

run_model()
# Out:
# <div><p>[ 1/10] Train Loss = 2.2771; Valid Loss = 2.2298; Valid Accuracy = 18.6%</p><p>[ 2/10] Train Loss = 2.1848; Valid Loss = 2.1378; Valid Accuracy = 25.4%</p><p>[ 3/10] Train Loss = 2.0814; Valid Loss = 2.0204; Valid Accuracy = 36.0%</p><p>[ 4/10] Train Loss = 1.9486; Valid Loss = 1.8733; Valid Accuracy = 35.9%</p><p>[ 5/10] Train Loss = 1.7882; Valid Loss = 1.7050; Valid Accuracy = 39.0%</p><p>[ 6/10] Train Loss = 1.6178; Valid Loss = 1.5379; Valid Accuracy = 47.0%</p><p>[ 7/10] Train Loss = 1.4549; Valid Loss = 1.3833; Valid Accuracy = 53.1%</p><p>[ 8/10] Train Loss = 1.3086; Valid Loss = 1.2500; Valid Accuracy = 58.5%</p><p>[ 9/10] Train Loss = 1.1871; Valid Loss = 1.1438; Valid Accuracy = 63.1%</p><p>[10/10] Train Loss = 1.0921; Valid Loss = 1.0618; Valid Accuracy = 66.3%</p></div>
# [10/10] Train Loss = 1.0921; Valid Loss = 1.0618; Valid Accuracy = 66.3%

# %% [markdown]
# # Part 1: Expectation and Variance

# %% [markdown]
# To get a sense of how we might think about stochastic gradient descent, let's imagine a very simple stochastic optimizer in a somewhat ideal world.
#
# At each step our optimizer will have one of two possible outcomes:
#
# - With a $75\%$ chance (probability $0.75$), our optimizer works well and *decreases* the loss by $10$.
# - However with a $25\%$ chance (probability $0.25$) our optimizer gets a bad result and *increases* the loss by $20$.
#
# The code below simulates a loss trace for this world.

# %%
loss_trace = [0]
for i in range(100):
    if np.random.rand() < 0.75:
        loss_trace.append(loss_trace[-1] - 10)
    else:
        loss_trace.append(loss_trace[-1] + 20)

plt.plot(loss_trace); plt.xlabel('step'); plt.ylabel('loss');
plt.title('Our simulated optimizer');

# %% [markdown]
# #### **Q1** (5 points)
#
# Assuming our loss starts at $0$, (we'll say $L^{(0)} = 0$). What is the *expected value* of the loss after $100$ steps?

# %% [markdown]
# \begin{align*}
# E\left[L^{(100)}\right] &= \left(0.75\cdot (-10) + 0.25\cdot (20)\right)\cdot 100\\
# &= -250
# \end{align*}

# %% [markdown]
# #### **Q2** (10 points)
#
# What is the *variance* of the loss after 100 steps?

# %% [markdown]
# \begin{align*}
# \text{Var}\left[L^{(100)}\right] &= (E[X^2] - (E[X])^2)\cdot 100 \\
# &= \left((0.75\cdot (100) + 0.25\cdot (400)) - (-2.5^2)\right)\cdot 100 \\
# &= 16875
# \end{align*}

# %% [markdown]
# # Part 2: Optimizers

# %% [markdown]
# In this part, we'll implement and test some of the optimizers that we talked about in class.

# %% [markdown]
# #### **Q3** (10 points)
#
# Let's start with the *momentum optimizer*. Recall that the update equations for stochastic gradient descent with momentum can be written as follows:
#
# $$ \mathbf{v}^{(k+1)} \longleftarrow \beta \mathbf{v}^{(k)} + (1-\beta) \nabla_{\mathbf{w}} \textbf{Loss}(\mathbf{w}^{(k)}, \mathbf{x}_i, y_i)$$
# $$ \mathbf{w}^{(k+1)} \longleftarrow \mathbf{w}^{(k)} - \alpha v^{(k+1)}$$
#
# Refer to the SGDOptimizer implementation above to understand how our optimizer works. At a high level our optimizer class will:
# - Maintain a list of the parameters of a model.
# - Provide a `step()` method to update the parameters according to the update equations.
#
# As we saw last time, we assume that the optimizer is *not* responsible for computing gradients. When step is called, we assume each parameter knows the gradient of the loss with respect to itself. This value is stored in `parameter.grad`.
#
# Fill in the implementation of `MomentumOptimizer` below, according to the update equations above.

# %%
class MomentumOptimizer(SGDOptimizer):
    # Gradient descent with momentum
    def __init__(self, parameters, lr=0.01, mu=0.9):
        # Set the learning rate
        self.lr = lr
        # Set the momentum update rate
        self.mu = mu
        # Store the set of parameters that we'll be optimizing
        self.parameters = list(parameters)
        # Store the velocity for each parameter
        self.velocity = [torch.zeros_like(param) for param in self.parameters]

    def step(self):
        # Take a step of gradient descent
        for ind, parameter in enumerate(self.parameters):
            # First update the velocity
            self.velocity[ind] = self.mu*self.velocity[ind] + (1-self.mu)*parameter.grad

            # Then compute the update to the parameter
            update = self.lr*self.velocity[ind]

            # Finally update the parameter as before
            parameter -= update

# %% [markdown]
# #### **Q4** (5 points)
# Train and evaluate the model using the `MomentumOptimizer` by running the cell below. Do the results seem different from the `SGDOptimizer`? Why do you think this might be?

# %% [markdown]
#  There doesn't seem to be a significant difference between MomentumOptimizer and SGDOptimizer, though momentum does result in slightly better training loss, validation loss, and validation accuracy. This might be because while momentum helps speed up training when optimizing over a difficult cost surface such as a long narrow valley, the data in this dataset is fairly easy to optimize over and accelerating the progress is not as impactful.

# %%
run_model(optimizer=MomentumOptimizer)
# Out:
# <div><p>[ 1/10] Train Loss = 2.2828; Valid Loss = 2.2412; Valid Accuracy = 17.1%</p><p>[ 2/10] Train Loss = 2.1940; Valid Loss = 2.1448; Valid Accuracy = 22.0%</p><p>[ 3/10] Train Loss = 2.0814; Valid Loss = 2.0162; Valid Accuracy = 39.0%</p><p>[ 4/10] Train Loss = 1.9324; Valid Loss = 1.8489; Valid Accuracy = 47.9%</p><p>[ 5/10] Train Loss = 1.7530; Valid Loss = 1.6686; Valid Accuracy = 49.3%</p><p>[ 6/10] Train Loss = 1.5822; Valid Loss = 1.5144; Valid Accuracy = 52.7%</p><p>[ 7/10] Train Loss = 1.4424; Valid Loss = 1.3906; Valid Accuracy = 57.6%</p><p>[ 8/10] Train Loss = 1.3296; Valid Loss = 1.2896; Valid Accuracy = 60.1%</p><p>[ 9/10] Train Loss = 1.2365; Valid Loss = 1.2051; Valid Accuracy = 61.1%</p><p>[10/10] Train Loss = 1.1581; Valid Loss = 1.1340; Valid Accuracy = 62.1%</p></div>
# [10/10] Train Loss = 1.1581; Valid Loss = 1.1340; Valid Accuracy = 62.1%

# %% [markdown]
# #### **Q5** (5 points)
#
# Now let's try the *RMSProp optimizer*. Recall that the update equations for RMSProp can be written as follows:
#
# $$ \mathbf{s}^{(k+1)} \longleftarrow \beta \mathbf{s}^{(k)} + (1-\beta) (\nabla_{\mathbf{w}} \textbf{Loss}(\mathbf{w}^{(k)}, \mathbf{X}, \mathbf{y}))^2$$
# $$ \mathbf{w}^{(k+1)} \longleftarrow \mathbf{w}^{(k)} - \alpha \frac{\nabla_{\mathbf{w}} \textbf{Loss}(\mathbf{w}^{(k)}, \mathbf{X}, \mathbf{y})}{\sqrt{\mathbf{s}^{(k+1)} + \epsilon}}$$
#
#
# Fill in the implementation of `RMSPropOptimizer` below, according to the update equations above.

# %%
epsilon = 1e-7

class RMSPropOptimizer(SGDOptimizer):
    # RMSProp Optimizer
    def __init__(self, parameters, lr=0.01, beta=0.9):
        # Set the learning rate
        self.lr = lr
        # Set the scale update rate
        self.beta = beta
        # Store the set of parameters that we'll be optimizing
        self.parameters = list(parameters)

        # Store any values that you'll need for RMSProp here
        self.s = [torch.zeros_like(param) for param in self.parameters]

    def step(self):
        # Take a step of gradient descent
        for ind, parameter in enumerate(self.parameters):

            self.s[ind] = self.beta*self.s[ind]+(1-self.beta)*torch.mul(parameter.grad, parameter.grad)

            # Then compute the update to the parameter
            update = self.lr*(parameter.grad/torch.sqrt(self.s[ind]+epsilon))

            # Finally update the parameter as before
            parameter -= update

# %% [markdown]
# #### **Q6** (5 points)
# Train and evaluate the model using the `RMSPropOptimizer` by running the cell below. Do the results seem different from the `SGDOptimizer`? Why do you think this might be?

# %% [markdown]
# This time it does look significantly different from SGDOptimizer, since it converges much faster, at lower training and validation loss, and with higher validation accuracy. It seems from the equation that RMSProp scales the learning rate by the size of the running average of previous updates, with a bias for the most recent update, such that larger previous updates slows the current update, vise versa. In other words, it seems to approximate Newton's method and allows us to consider the curvature of the original function. Thus, it helps us converge faster because we're able to speed up learning where curvature is small, i.e., larger steps don't make us overshoot by much. It also helps us converge closer to the optimum by slowing down learning when curvature is large, i.e., when we are likely to overshoot by taking a larger step, so we end up closer to the minimum.

# %%
run_model(optimizer=RMSPropOptimizer)
# Out:
# <div><p>[ 1/10] Train Loss = 0.7490; Valid Loss = 0.5806; Valid Accuracy = 79.1%</p><p>[ 2/10] Train Loss = 0.4751; Valid Loss = 0.4801; Valid Accuracy = 83.0%</p><p>[ 3/10] Train Loss = 0.4303; Valid Loss = 0.4526; Valid Accuracy = 83.5%</p><p>[ 4/10] Train Loss = 0.4058; Valid Loss = 0.4258; Valid Accuracy = 84.7%</p><p>[ 5/10] Train Loss = 0.3888; Valid Loss = 0.4217; Valid Accuracy = 85.0%</p><p>[ 6/10] Train Loss = 0.3753; Valid Loss = 0.4268; Valid Accuracy = 84.6%</p><p>[ 7/10] Train Loss = 0.3660; Valid Loss = 0.4308; Valid Accuracy = 84.6%</p><p>[ 8/10] Train Loss = 0.3557; Valid Loss = 0.4158; Valid Accuracy = 85.1%</p><p>[ 9/10] Train Loss = 0.3487; Valid Loss = 0.4150; Valid Accuracy = 85.1%</p><p>[10/10] Train Loss = 0.3410; Valid Loss = 0.4372; Valid Accuracy = 84.3%</p></div>
# [10/10] Train Loss = 0.3410; Valid Loss = 0.4372; Valid Accuracy = 84.3%

# %% [markdown]
# #### **Q7** (5 points)
#
# Finally let's try the *Adam optimizer*. Recall that the update equations for Adam can be written as follows:
#
# $$ \mathbf{v}^{(k+1)} \longleftarrow \beta_1 \mathbf{v}^{(k)} + (1-\beta_1) \nabla_{\mathbf{w}} \textbf{Loss}(\mathbf{w}^{(k)}, \mathbf{X}, \mathbf{y})$$
# $$ \mathbf{s}^{(k+1)} \longleftarrow \beta_2 \mathbf{s}^{(k)} + (1-\beta_2) (\nabla_{\mathbf{w}} \textbf{Loss}(\mathbf{w}^{(k)}, \mathbf{X}, \mathbf{y}))^2$$
# $$ \mathbf{w}^{(k+1)} \longleftarrow \mathbf{w}^{(k)} - \alpha \frac{\frac{\mathbf{v}^{(k+1)}}{(1-\beta_1^k)}
# }{\sqrt{\frac{\mathbf{s}^{(k+1)}}{(1-\beta_2^k)} + \epsilon}}$$
#
#
# Fill in the implementation of `AdamOptimizer` below, according to the update equations above.

# %%
epsilon = 1e-7
class AdamOptimizer(SGDOptimizer):
    # Adam optimizer
    def __init__(self, parameters, lr=0.01, beta1=0.9, beta2=0.99):
        # Set the learning rate
        self.lr = lr
        # Set the scale update rate
        self.beta1 = beta1
        self.beta2 = beta2

        # Store the set of parameters that we'll be optimizing
        self.parameters = list(parameters)
        # Store any values that you'll need for Adam here
        self.velocity = [torch.zeros_like(param) for param in self.parameters]
        self.s = [torch.zeros_like(param) for param in self.parameters]

    def step(self):
        # Take a step of gradient descent
        for ind, parameter in enumerate(self.parameters):
            self.velocity[ind] = self.beta1*self.velocity[ind] + (1-self.beta1)*parameter.grad
            self.s[ind] = self.beta2*self.s[ind]+(1-self.beta2)*torch.mul(parameter.grad, parameter.grad)

            # Then compute the update to the parameter
            update = self.lr*((self.velocity[ind]/(1-self.beta1))/(torch.sqrt(self.s[ind]/(1-self.beta2)+epsilon)))

            # Finally update the parameter as before
            parameter -= update

# %% [markdown]
# #### **Q8** (5 points)
# Train and evaluate the model using the `AdamOptimizer` by running the cell below. Do the results seem different from the `SGDOptimizer`? Why do you think this might be?

# %% [markdown]
# The results seem very similar to RMSProp and are quite different from SGOptimizer. It seems to converge at around the same speed as the RMSpropOptimizer, at a slightly lower test and validation loss, and a slightly higher validation accuracy. This makes sense because Adam seems to be a combination of RMSprop and Momentum, where the numerator of the update captures momentum while the denominator captures RMSprop. Thus, it is expected that it produces results that are substantially better than SGDOptimizer and around the best performance of the two prior optimizers.

# %%
run_model(optimizer=AdamOptimizer)
# Out:
# <div><p>[ 1/10] Train Loss = 0.6674; Valid Loss = 0.5174; Valid Accuracy = 81.2%</p><p>[ 2/10] Train Loss = 0.4514; Valid Loss = 0.4674; Valid Accuracy = 83.5%</p><p>[ 3/10] Train Loss = 0.4163; Valid Loss = 0.4415; Valid Accuracy = 83.9%</p><p>[ 4/10] Train Loss = 0.3951; Valid Loss = 0.4274; Valid Accuracy = 84.7%</p><p>[ 5/10] Train Loss = 0.3820; Valid Loss = 0.4183; Valid Accuracy = 85.1%</p><p>[ 6/10] Train Loss = 0.3672; Valid Loss = 0.4045; Valid Accuracy = 85.7%</p><p>[ 7/10] Train Loss = 0.3579; Valid Loss = 0.4041; Valid Accuracy = 85.5%</p><p>[ 8/10] Train Loss = 0.3498; Valid Loss = 0.4046; Valid Accuracy = 85.4%</p><p>[ 9/10] Train Loss = 0.3415; Valid Loss = 0.3902; Valid Accuracy = 86.1%</p><p>[10/10] Train Loss = 0.3363; Valid Loss = 0.3961; Valid Accuracy = 85.6%</p></div>
# [10/10] Train Loss = 0.3363; Valid Loss = 0.3961; Valid Accuracy = 85.6%

# %% [markdown]
# # Part 2: Normalization and Residual Networks

# %% [markdown]
# #### **Q9** (5 points)
#
# Try training a 20 layer network by running the cell below. What do you notice happening? Why does this happen?

# %% [markdown]
# The network fails to converge at all and training loss, validation loss, and validation accuracy all remain more or less constant throughout training. This may be due to the depth of the network preventing it from optimizing (its might be getting stuck in local optima of a rugged loss surface, failing to learn incredibly complex functions, etc.), causing internal covariate shift which slows down convergence, and potentially causing vanishing/exploding gradients.

# %%
run_model(number_of_hidden_layers=20)
# Out:
# <div><p>[ 1/10] Train Loss = 2.3128; Valid Loss = 2.3125; Valid Accuracy = 10.0%</p><p>[ 2/10] Train Loss = 2.3122; Valid Loss = 2.3119; Valid Accuracy = 10.0%</p><p>[ 3/10] Train Loss = 2.3116; Valid Loss = 2.3113; Valid Accuracy = 10.0%</p><p>[ 4/10] Train Loss = 2.3111; Valid Loss = 2.3108; Valid Accuracy = 10.0%</p><p>[ 5/10] Train Loss = 2.3106; Valid Loss = 2.3104; Valid Accuracy = 10.0%</p><p>[ 6/10] Train Loss = 2.3101; Valid Loss = 2.3099; Valid Accuracy = 10.0%</p><p>[ 7/10] Train Loss = 2.3097; Valid Loss = 2.3095; Valid Accuracy = 10.0%</p><p>[ 8/10] Train Loss = 2.3093; Valid Loss = 2.3091; Valid Accuracy = 10.0%</p><p>[ 9/10] Train Loss = 2.3089; Valid Loss = 2.3087; Valid Accuracy = 10.0%</p><p>[10/10] Train Loss = 2.3085; Valid Loss = 2.3084; Valid Accuracy = 10.0%</p></div>
# [10/10] Train Loss = 2.3085; Valid Loss = 2.3084; Valid Accuracy = 10.0%

# %% [markdown]
# #### **Q10** (10 points)
#
# Let's try applying normalization, starting with *Layer Normalization*.
#
# Assume we have a data matrix $\mathbf{X} \in \mathbb{R}^{N \times d}$, (i.e. $\mathbf{X}$ is an $N \times d$ matrix), such that:
# $$N:\ \text{Number of observations}$$
# $$d:\ \text{Number of features}$$
# Then we can define layer normalization as a function that normalizes the *rows* of this matrix. We can define this function element-wise as:
# $$\text{LayerNorm}(\mathbf{X})_{ij} = \frac{\mathbf{X}_{ij} - \mathbf{\bar{x}}_i}{\sqrt{\mathbf{s}^2_{i} + \epsilon}}$$
# $$\mathbf{\bar{x}}_i = \frac{1}{d} \sum_{k=1}^d \mathbf{X}_{ik}, \quad \mathbf{s}^2_{i} = \frac{1}{d-1}\sum_{k=1}^d \big( \mathbf{X}_{ik} - \mathbf{\bar{x}}_i \big)^2$$
#
# Complete the implementation of Layer Normalization below:

# %%
epsilon = 1e-7
class LayerNorm(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        x = (x-x.mean(dim=1, keepdim=True))/torch.sqrt(x.var(dim=1, keepdim=True)+epsilon)
        return x

# Replace our Layer class with one that includes layer normalization
class LayerNormLayer(nn.Module):
    def __init__(self, in_dimensions, out_dimensions):
        super().__init__()
        self.linear = nn.Linear(in_dimensions, out_dimensions)
        self.layer_norm = LayerNorm()
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.linear(x)
        x = self.layer_norm(x)
        x = self.activation(x)
        return x

# %% [markdown]
# #### **Q11** (5 points)
#
# Train and evaluate a 20-layer network with layer normalization by running the cell below. What changed from the run without layer normalization? Why?

# %% [markdown]
# There is actually a significant level of improvement in loss and accuracy throughout training with layer normalization. This is because layer normalization may be able to alleviate the problem of vanishing/exploding gradients to some extent by forcing the features of each sample to have consistent mean and std, which allows for more stability in training and prevents learning from stalling.

# %%
run_model(number_of_hidden_layers=20, layer_type=LayerNormLayer)
# Out:
# <div><p>[ 1/10] Train Loss = 2.3426; Valid Loss = 2.2883; Valid Accuracy = 10.0%</p><p>[ 2/10] Train Loss = 2.2297; Valid Loss = 2.1571; Valid Accuracy = 29.5%</p><p>[ 3/10] Train Loss = 2.0835; Valid Loss = 2.0092; Valid Accuracy = 36.7%</p><p>[ 4/10] Train Loss = 1.9433; Valid Loss = 1.8894; Valid Accuracy = 39.8%</p><p>[ 5/10] Train Loss = 1.8377; Valid Loss = 1.7953; Valid Accuracy = 41.2%</p><p>[ 6/10] Train Loss = 1.7465; Valid Loss = 1.7120; Valid Accuracy = 43.7%</p><p>[ 7/10] Train Loss = 1.6629; Valid Loss = 1.6326; Valid Accuracy = 57.6%</p><p>[ 8/10] Train Loss = 1.5853; Valid Loss = 1.5620; Valid Accuracy = 58.1%</p><p>[ 9/10] Train Loss = 1.5133; Valid Loss = 1.4886; Valid Accuracy = 68.5%</p><p>[10/10] Train Loss = 1.4452; Valid Loss = 1.4241; Valid Accuracy = 70.5%</p></div>
# [10/10] Train Loss = 1.4452; Valid Loss = 1.4241; Valid Accuracy = 70.5%

# %% [markdown]
# #### **Q12** (10 points)
#
# Now let's try a *Batch Normalization*.
#
# Assume we have the same data matrix $\mathbf{X} \in \mathbb{R}^{N \times d}$ described above.
#
# *For a batch of data this would be a $B \times d$ matrix, but this distinction is not important from the perspective of our batch norm layer.*
#
# We can define batch normalization as a function that normalizes the *columns* of this matrix. We can define this function element-wise as:
# $$\text{BatchNorm}(\mathbf{X})_{ij} = \frac{\mathbf{X}_{ij} - \mathbf{\bar{x}}_j}{\sqrt{\mathbf{s}^2_{j} + \epsilon}}$$
# $$\mathbf{\bar{x}}_j = \frac{1}{N} \sum_{k=1}^N \mathbf{X}_{kj}, \quad \mathbf{s}^2_{j} = \frac{1}{N-1}\sum_{k=1}^N \big( \mathbf{X}_{kj} - \mathbf{\bar{x}}_j \big)^2$$
# Recall that at *training time* we will also update running estimates of the batch mean and variance:
# $$\mathbf{\bar{\mu}}_j^{(k+1)} \longleftarrow \beta \mathbf{\bar{\mu}}^{(k)}_j + (1-\beta) \mathbf{\bar{x}}_j$$
# $$\mathbf{\bar{\sigma}}_j^{2(k+1)} \longleftarrow \beta \mathbf{\bar{\sigma}}^{2(k)}_j + (1-\beta) \mathbf{\bar{s}}^2_j$$
# At *test/evaluation* time we will use these estimates:
# $$\underset{\text{Test}}{\text{BatchNorm}}(\mathbf{X})_{ij} = \frac{\mathbf{X}_{ij} - \mathbf{\bar{\mu}}_j}{\sqrt{\mathbf{\bar{\sigma}}^2_{j} + \epsilon}}$$
#
# Complete the implementation of Batch Normalization below:

# %%
epsilon = 1e-7
class BatchNorm(nn.Module):
    def __init__(self, dimensions, beta=0.9):
        super().__init__()
        self.beta=beta
        self.running_mean = torch.zeros((1, dimensions))
        self.running_var = torch.ones((1, dimensions))

    def forward(self, x):
        # Needed for GPU compatibility
        self.running_mean = self.running_mean.to(x.device)
        self.running_var = self.running_var.to(x.device)

        if self.training:
            with torch.no_grad():
                self.running_mean = self.beta*self.running_mean + (1-self.beta)*x.mean(dim=0, keepdim=True)
                self.running_var = self.beta*self.running_var + (1-self.beta)*x.var(dim=0, keepdim=True)
            x = (x-self.running_mean)/torch.sqrt(self.running_var+epsilon)
            return x
        else:

            x = (x-self.running_mean)/torch.sqrt(self.running_var+epsilon)
            return x

class BatchNormLayer(nn.Module):
    def __init__(self, in_dimensions, out_dimensions):
        super().__init__()
        self.linear = nn.Linear(in_dimensions, out_dimensions)
        self.layer_norm = BatchNorm(out_dimensions)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.linear(x)
        x = self.layer_norm(x)
        x = self.activation(x)
        return x

# %% [markdown]
# #### **Q13** (5 points)
#
# Train and evaluate a 20-layer network with batch normalization by running the cell below. What changed from the run without normalization? Why?

# %% [markdown]
# The performance with batch normalization is better than without normalization. This may be due to batch normalization helping with internal covariate shift and thus speeding up convergence, which allows us to achieve better results faster.

# %%
run_model(number_of_hidden_layers=20, layer_type=BatchNormLayer)
# Out:
# <div><p>[ 1/10] Train Loss = 2.3320; Valid Loss = 2.3569; Valid Accuracy = 10.3%</p><p>[ 2/10] Train Loss = 2.2535; Valid Loss = 2.2069; Valid Accuracy = 18.7%</p><p>[ 3/10] Train Loss = 2.1276; Valid Loss = 2.0594; Valid Accuracy = 27.5%</p><p>[ 4/10] Train Loss = 2.0446; Valid Loss = 1.9931; Valid Accuracy = 29.7%</p><p>[ 5/10] Train Loss = 1.9792; Valid Loss = 1.9978; Valid Accuracy = 29.6%</p><p>[ 6/10] Train Loss = 1.9645; Valid Loss = 1.9854; Valid Accuracy = 30.3%</p><p>[ 7/10] Train Loss = 1.9682; Valid Loss = 2.0102; Valid Accuracy = 26.9%</p><p>[ 8/10] Train Loss = 1.9966; Valid Loss = 1.9974; Valid Accuracy = 27.6%</p><p>[ 9/10] Train Loss = 2.0004; Valid Loss = 2.0428; Valid Accuracy = 24.4%</p><p>[10/10] Train Loss = 2.0020; Valid Loss = 1.9816; Valid Accuracy = 26.2%</p></div>
# [10/10] Train Loss = 2.0020; Valid Loss = 1.9816; Valid Accuracy = 26.2%

# %% [markdown]
# #### **Q14** (10 points)
#
# Finally, let's try a residual network!
#
# Recall that a standard neural network layer with a `ReLU` activation can be written as:
#
# $$\phi(\mathbf{X}) = \text{ReLU}(\mathbf{X}\mathbf{W}^T + \mathbf{b})$$
#
# A *residual layer* in contrast can be written as:
# $$\phi_{res}(\mathbf{X}) = \text{ReLU}(\mathbf{X}\mathbf{W}^T + \mathbf{b}) + \mathbf{X}$$
#
# Complete the residual layer implementation below. You may assume that the input and output size of this layer are the same.

# %%
class ResidualLayer(nn.Module):
    def __init__(self, dimensions, *args):
        super().__init__()
        self.linear = nn.Linear(dimensions, dimensions)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.linear(x)
        x = self.activation(x) + x
        return x

# %% [markdown]
# #### **Q15** (5 points)
#
# Try running a residual network using the cell below. How did this network perform? Why?
# We see a signficant performance improvement compared to the original deep network without normalization or ResNet. This improvement may be due to the residual layer allowing for a shortcut that makes optimization easier by smoothing over the cost surface of the function.

# %%
run_model(number_of_hidden_layers=20, layer_type=ResidualLayer)
# Out:
# <div><p>[ 1/10] Train Loss = 2.3190; Valid Loss = 2.3106; Valid Accuracy = 8.8%</p><p>[ 2/10] Train Loss = 2.3031; Valid Loss = 2.2907; Valid Accuracy = 10.8%</p><p>[ 3/10] Train Loss = 2.2259; Valid Loss = 2.1064; Valid Accuracy = 20.5%</p><p>[ 4/10] Train Loss = 1.9386; Valid Loss = 1.8160; Valid Accuracy = 21.1%</p><p>[ 5/10] Train Loss = 1.6823; Valid Loss = 1.5710; Valid Accuracy = 26.9%</p><p>[ 6/10] Train Loss = 1.4264; Valid Loss = 1.2874; Valid Accuracy = 44.2%</p><p>[ 7/10] Train Loss = 1.1358; Valid Loss = 1.0403; Valid Accuracy = 55.9%</p><p>[ 8/10] Train Loss = 0.9729; Valid Loss = 1.0106; Valid Accuracy = 58.7%</p><p>[ 9/10] Train Loss = 0.8933; Valid Loss = 0.8839; Valid Accuracy = 64.0%</p><p>[10/10] Train Loss = 0.8408; Valid Loss = 0.8386; Valid Accuracy = 66.9%</p></div>
# [10/10] Train Loss = 0.8408; Valid Loss = 0.8386; Valid Accuracy = 66.9%
